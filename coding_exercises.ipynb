# %% [markdown]
# ## Learning basic programming concepts
# * happy
# * shy
# * angry

# %% [markdown]
# # Hello, World!
# + The following code was created as my first attempt at
# programming in this course. It is meant to help me understand how to write and
# run code in GitHub Codespaces.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # Printing
# step-by-Step Explanation by M365 copilot:
# + print() Function:
# print() is a built-in function in Python.
# Its job is to display text or data on the screen (usually the console).
# + Text Inside Quotes:
# "Hello, world!" is a string in Python.
# A string is a sequence of characters enclosed in double quotes (") or single quotes (').
# You can use either, but double quotes are common for readability.
# + Parentheses ():
# In Python 3, print requires parentheses because it is a function.
# Older versions (Python 2) allowed print "Hello, world!" without parentheses, but that’s outdated.
# + What Happens When You Run It?:
# Python reads the code.
# It calls the print() function with the argument "Hello, world!".
# The text appears on your screen:

# %%
print("Hello, world!")
# Out:
# Hello, world!
